# %%
import numpy as np
import pandas as pd
import math
import csv

# %%
def print_percentage(x, description=""):
    print(description + "{0:.2%}".format(x))

# %%
def experiment(am, al, size):
    # am: absolute mortality rate
    # al: absolute lapse rate
    # size: size for experiment
    
    fm = math.log(1/(1-am)) # force of mortality
    fl = math.log(1/(1-al)) # force of lapse
    print_percentage(1 - math.exp(-fl), "絶対解約率:")
    
    # generate sample data
    D = np.random.exponential(scale=1/fm, size=size) if fm > 0 else [1]*size
    L = np.random.exponential(scale=1/fl, size=size) if fl > 0 else [1]*size

    lapse_count = 0
    death_count = 0
    exposure_lengths = []
    exposure_lengths_extended = []
    for i in range(size):
        d = min(D[i], 1) 
        l = min(L[i], 1)
        x = min(d, l)
        x_extended = 1 if l < min(1, d) else min(d, l)
        exposure_lengths.append(x)
        exposure_lengths_extended.append(x_extended)
        lapse_count += 1 if l < min(1, d) else 0
        death_count += 1 if d < min(1, l) else 0

    efl = lapse_count/sum(exposure_lengths) # 最尤推定量
    with open('./sample.csv', mode='a') as f:
        writer = csv.writer(f, lineterminator='¥n')
        print(sum(exposure_lengths), lapse_count, death_count)
        print_percentage(1-math.exp(-efl), "解約力経由:")
        print_percentage(lapse_count/sum(exposure_lengths_extended), "長さ伸長方式:")
        print_percentage(lapse_count/sum(exposure_lengths), "長さ非伸長方式:")
        writer.writerow([1-math.exp(-efl), lapse_count/sum(exposure_lengths_extended),lapse_count/sum(exposure_lengths)])

# %%
for i in range(10):
    for j in range(10):
        am = i*0.1
        al = j*0.1
        print("experimetn start: ", am, al)
        experiment(am, al, 100000)
        print('---------------------------------')
# Out:
# experimetn start:  0.0 0.0
# 絶対解約率:0.00%
# 100000 0 0
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.0 0.1
# 絶対解約率:10.00%
# 94912.7024509308 10026 0
# 解約力経由:10.02%
# 長さ伸長方式:10.03%
# 長さ非伸長方式:10.56%
# ---------------------------------
# experimetn start:  0.0 0.2
# 絶対解約率:20.00%
# 89547.36227997883 20144 0
# 解約力経由:20.14%
# 長さ伸長方式:20.14%
# 長さ非伸長方式:22.50%
# ---------------------------------
# experimetn start:  0.0 0.30000000000000004
# 絶対解約率:30.00%
# 84142.34779579424 29879 0
# 解約力経由:29.89%
# 長さ伸長方式:29.88%
# 長さ非伸長方式:35.51%
# ---------------------------------
# experimetn start:  0.0 0.4
# 絶対解約率:40.00%
# 78332.84817852534 39941 0
# 解約力経由:39.94%
# 長さ伸長方式:39.94%
# 長さ非伸長方式:50.99%
# ---------------------------------
# experimetn start:  0.0 0.5
# 絶対解約率:50.00%
# 72155.24457198249 49944 0
# 解約力経由:49.95%
# 長さ伸長方式:49.94%
# 長さ非伸長方式:69.22%
# ---------------------------------
# experimetn start:  0.0 0.6000000000000001
# 絶対解約率:60.00%
# 65705.34829058906 59767 0
# 解約力経由:59.73%
# 長さ伸長方式:59.77%
# 長さ非伸長方式:90.96%
# ---------------------------------
# experimetn start:  0.0 0.7000000000000001
# 絶対解約率:70.00%
# 58307.23352602197 69748 0
# 解約力経由:69.77%
# 長さ伸長方式:69.75%
# 長さ非伸長方式:119.62%
# ---------------------------------
# experimetn start:  0.0 0.8
# 絶対解約率:80.00%
# 49902.208117669776 79818 0
# 解約力経由:79.80%
# 長さ伸長方式:79.82%
# 長さ非伸長方式:159.95%
# ---------------------------------
# experimetn start:  0.0 0.9
# 絶対解約率:90.00%
# 39089.2741559482 90170 0
# 解約力経由:90.04%
# 長さ伸長方式:90.17%
# 長さ非伸長方式:230.68%
# ---------------------------------
# experimetn start:  0.1 0.0
# 絶対解約率:0.00%
# 94866.26631580145 0 10078
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.1 0.1
# 絶対解約率:10.00%
# 90247.57140354623 9531 9326
# 解約力経由:10.02%
# 長さ伸長方式:10.01%
# 長さ非伸長方式:10.56%
# ---------------------------------
# experimetn start:  0.1 0.2
# 絶対解約率:20.00%
# 85134.09998921501 18912 9074
# 解約力経由:19.92%
# 長さ伸長方式:19.86%
# 長さ非伸長方式:22.21%
# ---------------------------------
# experimetn start:  0.1 0.30000000000000004
# 絶対解約率:30.00%
# 80038.51983383401 28603 8501
# 解約力経由:30.05%
# 長さ伸長方式:29.97%
# 長さ非伸長方式:35.74%
# ---------------------------------
# experimetn start:  0.1 0.4
# 絶対解約率:40.00%
# 74661.18904797849 38047 7879
# 解約力経由:39.93%
# 長さ伸長方式:39.79%
# 長さ非伸長方式:50.96%
# ---------------------------------
# experimetn start:  0.1 0.5
# 絶対解約率:50.00%
# 68852.18410807652 47768 7291
# 解約力経由:50.03%
# 長さ伸長方式:49.83%
# 長さ非伸長方式:69.38%
# ---------------------------------
# experimetn start:  0.1 0.6000000000000001
# 絶対解約率:60.00%
# 62702.064483609596 57339 6644
# 解約力経由:59.93%
# 長さ伸長方式:59.65%
# 長さ非伸長方式:91.45%
# ---------------------------------
# experimetn start:  0.1 0.7000000000000001
# 絶対解約率:70.00%
# 55744.68059612435 67332 5825
# 解約力経由:70.12%
# 長さ伸長方式:69.81%
# 長さ非伸長方式:120.79%
# ---------------------------------
# experimetn start:  0.1 0.8
# 絶対解約率:80.00%
# 47879.97567181788 76698 5150
# 解約力経由:79.85%
# 長さ伸長方式:79.31%
# 長さ非伸長方式:160.19%
# ---------------------------------
# experimetn start:  0.1 0.9
# 絶対解約率:90.00%
# 37784.70711223031 87030 3941
# 解約力経由:90.01%
# 長さ伸長方式:89.44%
# 長さ非伸長方式:230.33%
# ---------------------------------
# experimetn start:  0.2 0.0
# 絶対解約率:0.00%
# 89593.94075864174 0 20094
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.2 0.1
# 絶対解約率:10.00%
# 85260.62356866828 8983 19027
# 解約力経由:10.00%
# 長さ伸長方式:9.98%
# 長さ非伸長方式:10.54%
# ---------------------------------
# experimetn start:  0.2 0.2
# 絶対解約率:20.00%
# 80498.14656105766 18282 17920
# 解約力経由:20.32%
# 長さ伸長方式:20.24%
# 長さ非伸長方式:22.71%
# ---------------------------------
# experimetn start:  0.2 0.30000000000000004
# 絶対解約率:30.00%
# 75723.96223383879 27246 16895
# 解約力経由:30.22%
# 長さ伸長方式:30.03%
# 長さ非伸長方式:35.98%
# ---------------------------------
# experimetn start:  0.2 0.4
# 絶対解約率:40.00%
# 70927.52447549027 36162 15631
# 解約力経由:39.94%
# 長さ伸長方式:39.64%
# 長さ非伸長方式:50.98%
# ---------------------------------
# experimetn start:  0.2 0.5
# 絶対解約率:50.00%
# 65626.44826508587 45279 14596
# 解約力経由:49.84%
# 長さ伸長方式:49.42%
# 長さ非伸長方式:69.00%
# ---------------------------------
# experimetn start:  0.2 0.6000000000000001
# 絶対解約率:60.00%
# 60110.25469461731 54326 13122
# 解約力経由:59.50%
# 長さ伸長方式:58.91%
# 長さ非伸長方式:90.38%
# ---------------------------------
# experimetn start:  0.2 0.7000000000000001
# 絶対解約率:70.00%
# 53136.177849436026 63969 12053
# 解約力経由:70.00%
# 長さ伸長方式:69.07%
# 長さ非伸長方式:120.39%
# ---------------------------------
# experimetn start:  0.2 0.8
# 絶対解約率:80.00%
# 45751.6531771253 73894 10263
# 解約力経由:80.11%
# 長さ伸長方式:79.11%
# 長さ非伸長方式:161.51%
# ---------------------------------
# experimetn start:  0.2 0.9
# 絶対解約率:90.00%
# 36323.787584025355 83753 8221
# 解約力経由:90.03%
# 長さ伸長方式:88.83%
# 長さ非伸長方式:230.57%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.0
# 絶対解約率:0.00%
# 84118.07047320578 0 30038
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.1
# 絶対解約率:10.00%
# 79966.98119380779 8583 28666
# 解約力経由:10.18%
# 長さ伸長方式:10.14%
# 長さ非伸長方式:10.73%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.2
# 絶対解約率:20.00%
# 75648.30105086163 17099 27177
# 解約力経由:20.23%
# 長さ伸長方式:20.11%
# 長さ非伸長方式:22.60%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.30000000000000004
# 絶対解約率:30.00%
# 71518.96499356344 25470 25449
# 解約力経由:29.96%
# 長さ伸長方式:29.70%
# 長さ非伸長方式:35.61%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.4
# 絶対解約率:40.00%
# 66866.13311857259 34369 23575
# 解約力経由:40.19%
# 長さ伸長方式:39.71%
# 長さ非伸長方式:51.40%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.5
# 絶対解約率:50.00%
# 61736.58755360643 42788 22299
# 解約力経由:50.00%
# 長さ伸長方式:49.23%
# 長さ非伸長方式:69.31%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.6000000000000001
# 絶対解約率:60.00%
# 56581.24968362896 52009 19969
# 解約力経由:60.12%
# 長さ伸長方式:59.11%
# 長さ非伸長方式:91.92%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.7000000000000001
# 絶対解約率:70.00%
# 50541.86274075028 60832 18188
# 解約力経由:69.99%
# 長さ伸長方式:68.66%
# 長さ非伸長方式:120.36%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.8
# 絶対解約率:80.00%
# 43859.92434733302 70567 15446
# 解約力経由:79.99%
# 長さ伸長方式:78.49%
# 長さ非伸長方式:160.89%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.9
# 絶対解約率:90.00%
# 34983.33272404278 80594 12404
# 解約力経由:90.01%
# 長さ伸長方式:88.25%
# 長さ非伸長方式:230.38%
# ---------------------------------
# experimetn start:  0.4 0.0
# 絶対解約率:0.00%
# 78412.62678366319 0 39841
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.4 0.1
# 絶対解約率:10.00%
# 74615.85658144715 7823 38208
# 解約力経由:9.95%
# 長さ伸長方式:9.92%
# 長さ非伸長方式:10.48%
# ---------------------------------
# experimetn start:  0.4 0.2
# 絶対解約率:20.00%
# 70811.68138802017 15676 36442
# 解約力経由:19.86%
# 長さ伸長方式:19.68%
# 長さ非伸長方式:22.14%
# ---------------------------------
# experimetn start:  0.4 0.30000000000000004
# 絶対解約率:30.00%
# 66780.3682328614 23711 34352
# 解約力経由:29.89%
# 長さ伸長方式:29.52%
# 長さ非伸長方式:35.51%
# ---------------------------------
# experimetn start:  0.4 0.4
# 絶対解約率:40.00%
# 62370.27233513895 32137 32135
# 解約力経由:40.27%
# 長さ伸長方式:39.57%
# 長さ非伸長方式:51.53%
# ---------------------------------
# experimetn start:  0.4 0.5
# 絶対解約率:50.00%
# 58180.41658896264 40436 29316
# 解約力経由:50.09%
# 長さ伸長方式:49.12%
# 長さ非伸長方式:69.50%
# ---------------------------------
# experimetn start:  0.4 0.6000000000000001
# 絶対解約率:60.00%
# 53342.21918973098 48929 27001
# 解約力経由:60.04%
# 長さ伸長方式:58.63%
# 長さ非伸長方式:91.73%
# ---------------------------------
# experimetn start:  0.4 0.7000000000000001
# 絶対解約率:70.00%
# 47827.54280847035 57665 24315
# 解約力経由:70.05%
# 長さ伸長方式:68.27%
# 長さ非伸長方式:120.57%
# ---------------------------------
# experimetn start:  0.4 0.8
# 絶対解約率:80.00%
# 41621.809328456126 66524 21540
# 解約力経由:79.78%
# 長さ伸長方式:77.65%
# 長さ非伸長方式:159.83%
# ---------------------------------
# experimetn start:  0.4 0.9
# 絶対解約率:90.00%
# 33290.11566354353 76944 17158
# 解約力経由:90.09%
# 長さ伸長方式:87.61%
# 長さ非伸長方式:231.13%
# ---------------------------------
# experimetn start:  0.5 0.0
# 絶対解約率:0.00%
# 72186.87786268085 0 50070
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.5 0.1
# 絶対解約率:10.00%
# 68773.87589400107 7328 47996
# 解約力経由:10.11%
# 長さ伸長方式:10.05%
# 長さ非伸長方式:10.66%
# ---------------------------------
# experimetn start:  0.5 0.2
# 絶対解約率:20.00%
# 65443.645701736015 14655 45378
# 解約力経由:20.06%
# 長さ伸長方式:19.84%
# 長さ非伸長方式:22.39%
# ---------------------------------
# experimetn start:  0.5 0.30000000000000004
# 絶対解約率:30.00%
# 62184.2019685014 22052 42575
# 解約力経由:29.86%
# 長さ伸長方式:29.34%
# 長さ非伸長方式:35.46%
# ---------------------------------
# experimetn start:  0.5 0.4
# 絶対解約率:40.00%
# 58090.97545835167 29902 40265
# 解約力経由:40.23%
# 長さ伸長方式:39.35%
# 長さ非伸長方式:51.47%
# ---------------------------------
# experimetn start:  0.5 0.5
# 絶対解約率:50.00%
# 54244.557726817264 37211 37755
# 解約力経由:49.64%
# 長さ伸長方式:48.34%
# 長さ非伸長方式:68.60%
# ---------------------------------
# experimetn start:  0.5 0.6000000000000001
# 絶対解約率:60.00%
# 49612.79311025023 45606 34310
# 解約力経由:60.12%
# 長さ伸長方式:58.21%
# 長さ非伸長方式:91.92%
# ---------------------------------
# experimetn start:  0.5 0.7000000000000001
# 絶対解約率:70.00%
# 44887.21488452375 53949 30991
# 解約力経由:69.94%
# 長さ伸長方式:67.49%
# 長さ非伸長方式:120.19%
# ---------------------------------
# experimetn start:  0.5 0.8
# 絶対解約率:80.00%
# 39082.439176496795 62566 27401
# 解約力経由:79.83%
# 長さ伸長方式:76.80%
# 長さ非伸長方式:160.09%
# ---------------------------------
# experimetn start:  0.5 0.9
# 絶対解約率:90.00%
# 31781.0203693324 72915 22094
# 解約力経由:89.92%
# 長さ伸長方式:86.62%
# 長さ非伸長方式:229.43%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.0
# 絶対解約率:0.00%
# 65476.15024282942 0 60158
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.1
# 絶対解約率:10.00%
# 62704.070838451094 6561 57366
# 解約力経由:9.93%
# 長さ伸長方式:9.86%
# 長さ非伸長方式:10.46%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.2
# 絶対解約率:20.00%
# 59784.229603104155 13306 54543
# 解約力経由:19.95%
# 長さ伸長方式:19.69%
# 長さ非伸長方式:22.26%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 56623.490247228074 19948 51876
# 解約力経由:29.69%
# 長さ伸長方式:29.06%
# 長さ非伸長方式:35.23%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.4
# 絶対解約率:40.00%
# 53180.50249945013 26982 49083
# 解約力経由:39.79%
# 長さ伸長方式:38.67%
# 長さ非伸長方式:50.74%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.5
# 絶対解約率:50.00%
# 49730.6985617492 34424 45539
# 解約力経由:49.95%
# 長さ伸長方式:48.24%
# 長さ非伸長方式:69.22%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 45872.13467010955 42101 41799
# 解約力経由:60.06%
# 長さ伸長方式:57.66%
# 長さ非伸長方式:91.78%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 41394.9462644713 50128 38029
# 解約力経由:70.21%
# 長さ伸長方式:67.04%
# 長さ非伸長方式:121.10%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.8
# 絶対解約率:80.00%
# 36608.38489369751 58617 33388
# 解約力経由:79.83%
# 長さ伸長方式:76.18%
# 長さ非伸長方式:160.12%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.9
# 絶対解約率:90.00%
# 29691.81726665368 68732 27240
# 解約力経由:90.12%
# 長さ伸長方式:85.91%
# 長さ非伸長方式:231.48%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.0
# 絶対解約率:0.00%
# 58221.27415963278 0 69879
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.1
# 絶対解約率:10.00%
# 55841.40070866124 5865 67044
# 解約力経由:9.97%
# 長さ伸長方式:9.87%
# 長さ非伸長方式:10.50%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.2
# 絶対解約率:20.00%
# 53420.23763905082 11838 64140
# 解約力経由:19.88%
# 長さ伸長方式:19.52%
# 長さ非伸長方式:22.16%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 50622.12048435452 18045 61148
# 解約力経由:29.99%
# 長さ伸長方式:29.18%
# 長さ非伸長方式:35.65%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.4
# 絶対解約率:40.00%
# 48061.25044039108 24266 57452
# 解約力経由:39.64%
# 長さ伸長方式:38.23%
# 長さ非伸長方式:50.49%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.5
# 絶対解約率:50.00%
# 44784.70112106484 30981 53981
# 解約力経由:49.93%
# 長さ伸長方式:47.75%
# 長さ非伸長方式:69.18%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 41487.11045263914 37954 50130
# 解約力経由:59.94%
# 長さ伸長方式:56.91%
# 長さ非伸長方式:91.48%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 37778.02678648656 45341 45663
# 解約力経由:69.89%
# 長さ伸長方式:65.98%
# 長さ非伸長方式:120.02%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.8
# 絶対解約率:80.00%
# 33500.33126857016 53674 40305
# 解約力経由:79.85%
# 長さ伸長方式:75.12%
# 長さ非伸長方式:160.22%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.9
# 絶対解約率:90.00%
# 27648.95740222414 63541 33487
# 解約力経由:89.96%
# 長さ伸長方式:84.68%
# 長さ非伸長方式:229.81%
# ---------------------------------
# experimetn start:  0.8 0.0
# 絶対解約率:0.00%
# 49575.34810536212 0 80014
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.8 0.1
# 絶対解約率:10.00%
# 47808.42524765485 5114 76870
# 解約力経由:10.14%
# 長さ伸長方式:10.02%
# 長さ非伸長方式:10.70%
# ---------------------------------
# experimetn start:  0.8 0.2
# 絶対解約率:20.00%
# 45737.71368866579 10273 73613
# 解約力経由:20.12%
# 長さ伸長方式:19.60%
# 長さ非伸長方式:22.46%
# ---------------------------------
# experimetn start:  0.8 0.30000000000000004
# 絶対解約率:30.00%
# 43549.13303485583 15699 70470
# 解約力経由:30.27%
# 長さ伸長方式:29.13%
# 長さ非伸長方式:36.05%
# ---------------------------------
# experimetn start:  0.8 0.4
# 絶対解約率:40.00%
# 41419.51243952482 21150 66911
# 解約力経由:39.99%
# 長さ伸長方式:38.14%
# 長さ非伸長方式:51.06%
# ---------------------------------
# experimetn start:  0.8 0.5
# 絶対解約率:50.00%
# 39157.92922966612 27128 62771
# 解約力経由:49.98%
# 長さ伸長方式:47.13%
# 長さ非伸長方式:69.28%
# ---------------------------------
# experimetn start:  0.8 0.6000000000000001
# 絶対解約率:60.00%
# 36411.01444397434 33419 58521
# 解約力経由:60.06%
# 長さ伸長方式:56.16%
# 長さ非伸長方式:91.78%
# ---------------------------------
# experimetn start:  0.8 0.7000000000000001
# 絶対解約率:70.00%
# 33511.68623977777 40212 53762
# 解約力経由:69.88%
# 長さ伸長方式:64.97%
# 長さ非伸長方式:119.99%
# ---------------------------------
# experimetn start:  0.8 0.8
# 絶対解約率:80.00%
# 29869.81974113843 48079 47936
# 解約力経由:80.00%
# 長さ伸長方式:74.02%
# 長さ非伸長方式:160.96%
# ---------------------------------
# experimetn start:  0.8 0.9
# 絶対解約率:90.00%
# 25046.49834997031 57789 40279
# 解約力経由:90.05%
# 長さ伸長方式:83.51%
# 長さ非伸長方式:230.73%
# ---------------------------------
# experimetn start:  0.9 0.0
# 絶対解約率:0.00%
# 39280.12405141476 0 89865
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.9 0.1
# 絶対解約率:10.00%
# 37679.53786689911 3999 87141
# 解約力経由:10.07%
# 長さ伸長方式:9.89%
# 長さ非伸長方式:10.61%
# ---------------------------------
# experimetn start:  0.9 0.2
# 絶対解約率:20.00%
# 36483.96388578589 8175 83899
# 解約力経由:20.07%
# 長さ伸長方式:19.41%
# 長さ非伸長方式:22.41%
# ---------------------------------
# experimetn start:  0.9 0.30000000000000004
# 絶対解約率:30.00%
# 34958.25134580011 12381 80564
# 解約力経由:29.82%
# 長さ伸長方式:28.40%
# 長さ非伸長方式:35.42%
# ---------------------------------
# experimetn start:  0.9 0.4
# 絶対解約率:40.00%
# 33283.104158962604 17238 76775
# 解約力経由:40.42%
# 長さ伸長方式:37.85%
# 長さ非伸長方式:51.79%
# ---------------------------------
# experimetn start:  0.9 0.5
# 絶対解約率:50.00%
# 31717.066245996877 22031 73014
# 解約力経由:50.07%
# 長さ伸長方式:46.36%
# 長さ非伸長方式:69.46%
# ---------------------------------
# experimetn start:  0.9 0.6000000000000001
# 絶対解約率:60.00%
# 29905.267138541134 27474 68455
# 解約力経由:60.10%
# 長さ伸長方式:55.00%
# 長さ非伸長方式:91.87%
# ---------------------------------
# experimetn start:  0.9 0.7000000000000001
# 絶対解約率:70.00%
# 27744.471421702325 33074 63795
# 解約力経由:69.64%
# 長さ伸長方式:63.11%
# 長さ非伸長方式:119.21%
# ---------------------------------
# experimetn start:  0.9 0.8
# 絶対解約率:80.00%
# 25221.45457976642 40469 57510
# 解約力経由:79.90%
# 長さ伸長方式:72.05%
# 長さ非伸長方式:160.45%
# ---------------------------------
# experimetn start:  0.9 0.9
# 絶対解約率:90.00%
# 21558.112432216007 49423 49594
# 解約力経由:89.90%
# 長さ伸長方式:81.42%
# 長さ非伸長方式:229.25%
# ---------------------------------
