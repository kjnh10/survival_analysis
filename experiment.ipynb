# %%
import numpy as np
import pandas as pd
import math
import csv

# %%
def print_percentage(x, description=""):
    print(description + "{0:.2%}".format(x))

# %%
def experiment(am, al, size):
    # am: absolute mortality rate
    # al: absolute lapse rate
    # size: size for experiment
    
    fm = math.log(1/(1-am)) # force of mortality
    fl = math.log(1/(1-al)) # force of lapse
    print_percentage(1 - math.exp(-fl), "絶対解約率:")
    
    # generate sample data
    D = np.random.exponential(scale=1/fm, size=size) if fm > 0 else [1]*size
    L = np.random.exponential(scale=1/fl, size=size) if fl > 0 else [1]*size

    lapse_count = 0
    death_count = 0
    exposure_lengths = []
    exposure_lengths_extended = []
    for i in range(size):
        d = min(D[i], 1) 
        l = min(L[i], 1)
        x = min(d, l)
        x_extended = 1 if l < min(1, d) else min(d, l)
        exposure_lengths.append(x)
        exposure_lengths_extended.append(x_extended)
        lapse_count += 1 if l < min(1, d) else 0
        death_count += 1 if d < min(1, l) else 0
    efl = lapse_count/sum(exposure_lengths) # 最尤推定量
    a.append(1-math.exp(-efl))
    b.append(lapse_count/sum(exposure_lengths_extended))
    c.append(lapse_count/sum(exposure_lengths))

    print(sum(exposure_lengths), lapse_count, death_count)
    print_percentage(1-math.exp(-efl), "解約力経由:")
    print_percentage(lapse_count/sum(exposure_lengths_extended), "長さ伸長方式:")
    print_percentage(lapse_count/sum(exposure_lengths), "長さ非伸長方式:")

# %%
global a,b,c
a,b,c = [],[],[]
AM, AL = [],[]
for i in range(10):
    for j in range(10):
        am = i*0.1
        al = j*0.1
        AM.append(am)
        AL.append(al)
        print("experimetn start: ", am, al)
        experiment(am, al, 1000000)
        print('---------------------------------')
# Out:
# experimetn start:  0.0 0.0
# 絶対解約率:0.00%
# 1000000 0 0
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.0 0.1
# 絶対解約率:10.00%
# 948930.3722405371 100360 0
# 解約力経由:10.04%
# 長さ伸長方式:10.04%
# 長さ非伸長方式:10.58%
# ---------------------------------
# experimetn start:  0.0 0.2
# 絶対解約率:20.00%
# 896153.7292633608 199855 0
# 解約力経由:19.99%
# 長さ伸長方式:19.99%
# 長さ非伸長方式:22.30%
# ---------------------------------
# experimetn start:  0.0 0.30000000000000004
# 絶対解約率:30.00%
# 841341.8144523135 299795 0
# 解約力経由:29.98%
# 長さ伸長方式:29.98%
# 長さ非伸長方式:35.63%
# ---------------------------------
# experimetn start:  0.0 0.4
# 絶対解約率:40.00%
# 783052.1050583345 399861 0
# 解約力経由:39.99%
# 長さ伸長方式:39.99%
# 長さ非伸長方式:51.06%
# ---------------------------------
# experimetn start:  0.0 0.5
# 絶対解約率:50.00%
# 720816.6468383052 500644 0
# 解約力経由:50.07%
# 長さ伸長方式:50.06%
# 長さ非伸長方式:69.46%
# ---------------------------------
# experimetn start:  0.0 0.6000000000000001
# 絶対解約率:60.00%
# 654695.8981811522 599808 0
# 解約力経由:59.99%
# 長さ伸長方式:59.98%
# 長さ非伸長方式:91.62%
# ---------------------------------
# experimetn start:  0.0 0.7000000000000001
# 絶対解約率:70.00%
# 581486.6431885724 699817 0
# 解約力経由:69.99%
# 長さ伸長方式:69.98%
# 長さ非伸長方式:120.35%
# ---------------------------------
# experimetn start:  0.0 0.8
# 絶対解約率:80.00%
# 497511.7977307064 799662 0
# 解約力経由:79.96%
# 長さ伸長方式:79.97%
# 長さ非伸長方式:160.73%
# ---------------------------------
# experimetn start:  0.0 0.9
# 絶対解約率:90.00%
# 390782.2060112147 900385 0
# 解約力経由:90.01%
# 長さ伸長方式:90.04%
# 長さ非伸長方式:230.41%
# ---------------------------------
# experimetn start:  0.1 0.0
# 絶対解約率:0.00%
# 949362.847489929 0 99542
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.1 0.1
# 絶対解約率:10.00%
# 901462.3724486931 95468 94869
# 解約力経由:10.05%
# 長さ伸長方式:10.04%
# 長さ非伸長方式:10.59%
# ---------------------------------
# experimetn start:  0.1 0.2
# 絶対解約率:20.00%
# 852146.6588561028 190231 89979
# 解約力経由:20.01%
# 長さ伸長方式:19.97%
# 長さ非伸長方式:22.32%
# ---------------------------------
# experimetn start:  0.1 0.30000000000000004
# 絶対解約率:30.00%
# 801088.9439262027 285074 84596
# 解約力経由:29.94%
# 長さ伸長方式:29.86%
# 長さ非伸長方式:35.59%
# ---------------------------------
# experimetn start:  0.1 0.4
# 絶対解約率:40.00%
# 746722.413484976 380610 78727
# 解約力経由:39.93%
# 長さ伸長方式:39.79%
# 長さ非伸長方式:50.97%
# ---------------------------------
# experimetn start:  0.1 0.5
# 絶対解約率:50.00%
# 688694.0017727406 476955 72706
# 解約力経由:49.97%
# 長さ伸長方式:49.74%
# 長さ非伸長方式:69.25%
# ---------------------------------
# experimetn start:  0.1 0.6000000000000001
# 絶対解約率:60.00%
# 626884.8417274597 573692 65594
# 解約力経由:59.95%
# 長さ伸長方式:59.65%
# 長さ非伸長方式:91.51%
# ---------------------------------
# experimetn start:  0.1 0.7000000000000001
# 絶対解約率:70.00%
# 557480.5759059663 671678 58567
# 解約力経由:70.03%
# 長さ伸長方式:69.65%
# 長さ非伸長方式:120.48%
# ---------------------------------
# experimetn start:  0.1 0.8
# 絶対解約率:80.00%
# 478900.5409744842 768709 50684
# 解約力経由:79.91%
# 長さ伸長方式:79.42%
# 長さ非伸長方式:160.52%
# ---------------------------------
# experimetn start:  0.1 0.9
# 絶対解約率:90.00%
# 377664.4794738046 870407 39999
# 解約力経由:90.02%
# 長さ伸長方式:89.48%
# 長さ非伸長方式:230.47%
# ---------------------------------
# experimetn start:  0.2 0.0
# 絶対解約率:0.00%
# 896153.5451236343 0 200116
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.2 0.1
# 絶対解約率:10.00%
# 851731.5968593515 89749 190708
# 解約力経由:10.00%
# 長さ伸長方式:9.98%
# 長さ非伸長方式:10.54%
# ---------------------------------
# experimetn start:  0.2 0.2
# 絶対解約率:20.00%
# 806437.1759386964 180175 180013
# 解約力経由:20.02%
# 長さ伸長方式:19.95%
# 長さ非伸長方式:22.34%
# ---------------------------------
# experimetn start:  0.2 0.30000000000000004
# 絶対解約率:30.00%
# 758811.7225175088 270562 169749
# 解約力経由:29.99%
# 長さ伸長方式:29.84%
# 長さ非伸長方式:35.66%
# ---------------------------------
# experimetn start:  0.2 0.4
# 絶対解約率:40.00%
# 708343.3518557178 361654 158494
# 解約力経由:39.98%
# 長さ伸長方式:39.69%
# 長さ非伸長方式:51.06%
# ---------------------------------
# experimetn start:  0.2 0.5
# 絶対解約率:50.00%
# 654300.2220542608 454477 146427
# 解約力経由:50.07%
# 長さ伸長方式:49.63%
# 長さ非伸長方式:69.46%
# ---------------------------------
# experimetn start:  0.2 0.6000000000000001
# 絶対解約率:60.00%
# 596637.2360351507 547470 132576
# 解約力経由:60.05%
# 長さ伸長方式:59.43%
# 長さ非伸長方式:91.76%
# ---------------------------------
# experimetn start:  0.2 0.7000000000000001
# 絶対解約率:70.00%
# 532397.7214164969 641853 118470
# 解約力経由:70.05%
# 長さ伸長方式:69.23%
# 長さ非伸長方式:120.56%
# ---------------------------------
# experimetn start:  0.2 0.8
# 絶対解約率:80.00%
# 458467.0742275753 737352 102345
# 解約力経由:79.98%
# 長さ伸長方式:78.95%
# 長さ非伸長方式:160.83%
# ---------------------------------
# experimetn start:  0.2 0.9
# 絶対解約率:90.00%
# 364163.48472915316 838303 82005
# 解約力経由:89.99%
# 長さ伸長方式:88.85%
# 長さ非伸長方式:230.20%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.0
# 絶対解約率:0.00%
# 840987.3763406052 0 300138
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.1
# 絶対解約率:10.00%
# 801071.4663544969 84178 285464
# 解約力経由:9.97%
# 長さ伸長方式:9.94%
# 長さ非伸長方式:10.51%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.2
# 絶対解約率:20.00%
# 758798.2966422266 169872 270655
# 解約力経由:20.06%
# 長さ伸長方式:19.94%
# 長さ非伸長方式:22.39%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.30000000000000004
# 絶対解約率:30.00%
# 715500.5953365907 254821 254327
# 解約力経由:29.96%
# 長さ伸長方式:29.70%
# 長さ非伸長方式:35.61%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.4
# 絶対解約率:40.00%
# 668287.8472425401 342143 238406
# 解約力経由:40.07%
# 長さ伸長方式:39.61%
# 長さ非伸長方式:51.20%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.5
# 絶対解約率:50.00%
# 618899.6059205602 429894 220495
# 解約力経由:50.07%
# 長さ伸長方式:49.36%
# 長さ非伸長方式:69.46%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.6000000000000001
# 絶対解約率:60.00%
# 565420.6774614624 517847 201963
# 解約力経由:59.98%
# 長さ伸長方式:58.97%
# 長さ非伸長方式:91.59%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.7000000000000001
# 絶対解約率:70.00%
# 506258.0234252522 609828 180288
# 解約力経由:70.02%
# 長さ伸長方式:68.72%
# 長さ非伸長方式:120.46%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.8
# 絶対解約率:80.00%
# 437354.93008841376 704442 155874
# 解約力経由:80.02%
# 長さ伸長方式:78.43%
# 長さ非伸長方式:161.07%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.9
# 絶対解約率:90.00%
# 349714.6637700448 805489 124706
# 解約力経由:90.01%
# 長さ伸長方式:88.24%
# 長さ非伸長方式:230.33%
# ---------------------------------
# experimetn start:  0.4 0.0
# 絶対解約率:0.00%
# 782843.0253025746 0 399871
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.4 0.1
# 絶対解約率:10.00%
# 746280.5753410251 78734 381745
# 解約力経由:10.01%
# 長さ伸長方式:9.97%
# 長さ非伸長方式:10.55%
# ---------------------------------
# experimetn start:  0.4 0.2
# 絶対解約率:20.00%
# 709134.7655143575 157515 362214
# 解約力経由:19.92%
# 長さ伸長方式:19.76%
# 長さ非伸長方式:22.21%
# ---------------------------------
# experimetn start:  0.4 0.30000000000000004
# 絶対解約率:30.00%
# 668878.0282913616 238581 341005
# 解約力経由:30.00%
# 長さ伸長方式:29.63%
# 長さ非伸長方式:35.67%
# ---------------------------------
# experimetn start:  0.4 0.4
# 絶対解約率:40.00%
# 626166.5208455806 319679 320577
# 解約力経由:39.98%
# 長さ伸長方式:39.33%
# 長さ非伸長方式:51.05%
# ---------------------------------
# experimetn start:  0.4 0.5
# 絶対解約率:50.00%
# 581750.8385595392 402530 296861
# 解約力経由:49.94%
# 長さ伸長方式:48.93%
# 長さ非伸長方式:69.19%
# ---------------------------------
# experimetn start:  0.4 0.6000000000000001
# 絶対解約率:60.00%
# 532529.7548652634 489053 270846
# 解約力経由:60.08%
# 長さ伸長方式:58.68%
# 長さ非伸長方式:91.84%
# ---------------------------------
# experimetn start:  0.4 0.7000000000000001
# 絶対解約率:70.00%
# 477697.62914753385 576088 244327
# 解約力経由:70.06%
# 長さ伸長方式:68.22%
# 長さ非伸長方式:120.60%
# ---------------------------------
# experimetn start:  0.4 0.8
# 絶対解約率:80.00%
# 415432.6229217674 667325 212379
# 解約力経由:79.94%
# 長さ伸長方式:77.69%
# 長さ非伸長方式:160.63%
# ---------------------------------
# experimetn start:  0.4 0.9
# 絶対解約率:90.00%
# 334261.2612452129 769230 170763
# 解約力経由:89.99%
# 長さ伸長方式:87.50%
# 長さ非伸長方式:230.13%
# ---------------------------------
# experimetn start:  0.5 0.0
# 絶対解約率:0.00%
# 721296.1419254144 0 499929
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.5 0.1
# 絶対解約率:10.00%
# 688842.3373153174 72957 477457
# 解約力経由:10.05%
# 長さ伸長方式:9.99%
# 長さ非伸長方式:10.59%
# ---------------------------------
# experimetn start:  0.5 0.2
# 絶対解約率:20.00%
# 654636.3757133648 145686 454775
# 解約力経由:19.95%
# 長さ伸長方式:19.73%
# 長さ非伸長方式:22.25%
# ---------------------------------
# experimetn start:  0.5 0.30000000000000004
# 絶対解約率:30.00%
# 619081.6180842406 220205 429769
# 解約力経由:29.93%
# 長さ伸長方式:29.43%
# 長さ非伸長方式:35.57%
# ---------------------------------
# experimetn start:  0.5 0.4
# 絶対解約率:40.00%
# 581542.4350880162 297182 402599
# 解約力経由:40.01%
# 長さ伸長方式:39.14%
# 長さ非伸長方式:51.10%
# ---------------------------------
# experimetn start:  0.5 0.5
# 絶対解約率:50.00%
# 541338.2774844272 374011 375687
# 解約力経由:49.89%
# 長さ伸長方式:48.57%
# 長さ非伸長方式:69.09%
# ---------------------------------
# experimetn start:  0.5 0.6000000000000001
# 絶対解約率:60.00%
# 497696.566632888 454819 344721
# 解約力経由:59.90%
# 長さ伸長方式:58.06%
# 長さ非伸長方式:91.38%
# ---------------------------------
# experimetn start:  0.5 0.7000000000000001
# 絶対解約率:70.00%
# 448460.59816609486 539473 310278
# 解約力経由:69.97%
# 長さ伸長方式:67.57%
# 長さ非伸長方式:120.29%
# ---------------------------------
# experimetn start:  0.5 0.8
# 絶対解約率:80.00%
# 390731.24103384576 628666 271557
# 解約力経由:79.99%
# 長さ伸長方式:77.03%
# 長さ非伸長方式:160.89%
# ---------------------------------
# experimetn start:  0.5 0.9
# 絶対解約率:90.00%
# 317480.72555387364 729735 219891
# 解約力経由:89.96%
# 長さ伸長方式:86.67%
# 長さ非伸長方式:229.85%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.0
# 絶対解約率:0.00%
# 655040.7750584155 0 599703
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.1
# 絶対解約率:10.00%
# 626335.0272533218 66003 573936
# 解約力経由:10.00%
# 長さ伸長方式:9.93%
# 長さ非伸長方式:10.54%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.2
# 絶対解約率:20.00%
# 596402.365601419 133949 546584
# 解約力経由:20.12%
# 長さ伸長方式:19.82%
# 長さ非伸長方式:22.46%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 566060.7866944136 201381 518435
# 解約力経由:29.94%
# 長さ伸長方式:29.30%
# 長さ非伸長方式:35.58%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.4
# 絶対解約率:40.00%
# 532424.463002064 272772 487059
# 解約力経由:40.09%
# 長さ伸長方式:38.96%
# 長さ非伸長方式:51.23%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.5
# 絶対解約率:50.00%
# 497135.20818199246 344862 455495
# 解約力経由:50.03%
# 長さ伸長方式:48.29%
# 長さ非伸長方式:69.37%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 458399.4633083137 420944 418645
# 解約力経由:60.08%
# 長さ伸長方式:57.66%
# 長さ非伸長方式:91.83%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 415154.23353243724 498913 381241
# 解約力経由:69.93%
# 長さ伸長方式:66.83%
# 長さ非伸長方式:120.18%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.8
# 絶対解約率:80.00%
# 364717.59033017926 586589 332936
# 解約力経由:79.98%
# 長さ伸長方式:76.17%
# 長さ非伸長方式:160.83%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.9
# 絶対解約率:90.00%
# 298111.648189065 687026 272959
# 解約力経由:90.02%
# 長さ伸長方式:85.85%
# 長さ非伸長方式:230.46%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.0
# 絶対解約率:0.00%
# 581776.6665297684 0 699534
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.1
# 絶対解約率:10.00%
# 557785.4160653007 58921 670713
# 解約力経由:10.02%
# 長さ伸長方式:9.93%
# 長さ非伸長方式:10.56%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.2
# 絶対解約率:20.00%
# 532423.3308767553 118287 642172
# 解約力経由:19.92%
# 長さ伸長方式:19.55%
# 長さ非伸長方式:22.22%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 507058.93499491666 179980 609148
# 解約力経由:29.88%
# 長さ伸長方式:29.06%
# 長さ非伸長方式:35.49%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.4
# 絶対解約率:40.00%
# 477977.10077095474 244616 575241
# 解約力経由:40.06%
# 長さ伸長方式:38.61%
# 長さ非伸長方式:51.18%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.5
# 絶対解約率:50.00%
# 448169.0512483983 311376 538422
# 解約力経由:50.08%
# 長さ伸長方式:47.87%
# 長さ非伸長方式:69.48%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 415007.55482534325 380050 500353
# 解約力経由:59.98%
# 長さ伸長方式:56.94%
# 長さ非伸長方式:91.58%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 377974.271121082 454576 455306
# 解約力経由:69.96%
# 長さ伸長方式:65.99%
# 長さ非伸長方式:120.27%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.8
# 絶対解約率:80.00%
# 334181.56902539846 538329 401726
# 解約力経由:80.03%
# 長さ伸長方式:75.25%
# 長さ非伸長方式:161.09%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.9
# 絶対解約率:90.00%
# 277251.2039632052 636882 332699
# 解約力経由:89.95%
# 長さ伸長方式:84.68%
# 長さ非伸長方式:229.71%
# ---------------------------------
# experimetn start:  0.8 0.0
# 絶対解約率:0.00%
# 497286.3788328435 0 799902
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.8 0.1
# 絶対解約率:10.00%
# 478199.89598512277 50479 769671
# 解約力経由:10.02%
# 長さ伸長方式:9.89%
# 長さ非伸長方式:10.56%
# ---------------------------------
# experimetn start:  0.8 0.2
# 絶対解約率:20.00%
# 457878.3480631656 101873 738436
# 解約力経由:19.95%
# 長さ伸長方式:19.45%
# 長さ非伸長方式:22.25%
# ---------------------------------
# experimetn start:  0.8 0.30000000000000004
# 絶対解約率:30.00%
# 438108.49673645524 155413 704144
# 解約力経由:29.86%
# 長さ伸長方式:28.79%
# 長さ非伸長方式:35.47%
# ---------------------------------
# experimetn start:  0.8 0.4
# 絶対解約率:40.00%
# 414993.8764393321 211677 668931
# 解約力経由:39.95%
# 長さ伸長方式:38.10%
# 長さ非伸長方式:51.01%
# ---------------------------------
# experimetn start:  0.8 0.5
# 絶対解約率:50.00%
# 390427.951623286 271778 628925
# 解約力経由:50.15%
# 長さ伸長方式:47.33%
# 長さ非伸長方式:69.61%
# ---------------------------------
# experimetn start:  0.8 0.6000000000000001
# 絶対解約率:60.00%
# 364178.0645382214 333869 586449
# 解約力経由:60.02%
# 長さ伸長方式:56.12%
# 長さ非伸長方式:91.68%
# ---------------------------------
# experimetn start:  0.8 0.7000000000000001
# 絶対解約率:70.00%
# 334402.5683543962 402543 536945
# 解約力経由:69.99%
# 長さ伸長方式:64.97%
# 長さ非伸長方式:120.38%
# ---------------------------------
# experimetn start:  0.8 0.8
# 絶対解約率:80.00%
# 298133.5455111897 480078 480202
# 解約力経由:80.02%
# 長さ伸長方式:73.95%
# 長さ非伸長方式:161.03%
# ---------------------------------
# experimetn start:  0.8 0.9
# 絶対解約率:90.00%
# 250567.82645857014 576550 403481
# 解約力経由:89.98%
# 長さ伸長方式:83.37%
# 長さ非伸長方式:230.10%
# ---------------------------------
# experimetn start:  0.9 0.0
# 絶対解約率:0.00%
# 390432.5001955811 0 900120
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.9 0.1
# 絶対解約率:10.00%
# 378494.9843686822 40199 869772
# 解約力経由:10.08%
# 長さ伸長方式:9.90%
# 長さ非伸長方式:10.62%
# ---------------------------------
# experimetn start:  0.9 0.2
# 絶対解約率:20.00%
# 363914.62050482654 80709 839308
# 解約力経由:19.89%
# 長さ伸長方式:19.23%
# 長さ非伸長方式:22.18%
# ---------------------------------
# experimetn start:  0.9 0.30000000000000004
# 絶対解約率:30.00%
# 349961.05997349473 124131 805522
# 解約力経由:29.86%
# 長さ伸長方式:28.42%
# 長さ非伸長方式:35.47%
# ---------------------------------
# experimetn start:  0.9 0.4
# 絶対解約率:40.00%
# 333973.48980945704 170331 769458
# 解約力経由:39.95%
# 長さ伸長方式:37.47%
# 長さ非伸長方式:51.00%
# ---------------------------------
# experimetn start:  0.9 0.5
# 絶対解約率:50.00%
# 317003.8936627814 219178 730784
# 解約力経由:49.91%
# 長さ伸長方式:46.19%
# 長さ非伸長方式:69.14%
# ---------------------------------
# experimetn start:  0.9 0.6000000000000001
# 絶対解約率:60.00%
# 297588.19685512997 272654 687942
# 解約力経由:60.00%
# 長さ伸長方式:54.88%
# 長さ非伸長方式:91.62%
# ---------------------------------
# experimetn start:  0.9 0.7000000000000001
# 絶対解約率:70.00%
# 276697.03937828395 332915 637174
# 解約力経由:69.98%
# 長さ伸長方式:63.43%
# 長さ非伸長方式:120.32%
# ---------------------------------
# experimetn start:  0.9 0.8
# 絶対解約率:80.00%
# 250332.90931447764 402688 577535
# 解約力経由:79.98%
# 長さ伸長方式:72.11%
# 長さ非伸長方式:160.86%
# ---------------------------------
# experimetn start:  0.9 0.9
# 絶対解約率:90.00%
# 214884.18859248867 495648 494413
# 解約力経由:90.04%
# 長さ伸長方式:81.53%
# 長さ非伸長方式:230.66%
# ---------------------------------

# %%
pd.DataFrame(
    {'am':AM, 'al':AL, 'a':a,'b':b,'c':c}
).to_csv('./result.csv')
