# %%
import numpy as np
import pandas as pd
import math
import csv

# %%
def print_percentage(x, description=""):
    print(description + "{0:.2%}".format(x))

# %%
def experiment(am, al, size):
    # am: absolute mortality rate
    # al: absolute lapse rate
    # size: size for experiment
    
    fm = math.log(1/(1-am)) # force of mortality
    fl = math.log(1/(1-al)) # force of lapse
    print_percentage(1 - math.exp(-fl), "絶対解約率:")
    
    # generate sample data
    D = np.random.exponential(scale=1/fm, size=size) if fm > 0 else [1]*size
    L = np.random.exponential(scale=1/fl, size=size) if fl > 0 else [1]*size

    lapse_count = 0
    death_count = 0
    exposure_lengths = []
    exposure_lengths_extended = []
    for i in range(size):
        d = min(D[i], 1) 
        l = min(L[i], 1)
        x = min(d, l)
        x_extended = 1 if l < min(1, d) else min(d, l)
        exposure_lengths.append(x)
        exposure_lengths_extended.append(x_extended)
        lapse_count += 1 if l < min(1, d) else 0
        death_count += 1 if d < min(1, l) else 0
    efl = lapse_count/sum(exposure_lengths) # 最尤推定量
    a.append(1-math.exp(-efl))
    b.append(lapse_count/sum(exposure_lengths_extended))
    c.append(lapse_count/sum(exposure_lengths))

    print(sum(exposure_lengths), lapse_count, death_count)
    print_percentage(1-math.exp(-efl), "解約力経由:")
    print_percentage(lapse_count/sum(exposure_lengths_extended), "長さ伸長方式:")
    print_percentage(lapse_count/sum(exposure_lengths), "長さ非伸長方式:")

# %%
global a,b,c
a,b,c = [],[],[]
AM, AL = [],[]
for i in range(10):
    for j in range(10):
        am = i*0.1
        al = j*0.1
        AM.append(am)
        AL.append(al)
        print("experimetn start: ", am, al)
        experiment(am, al, 100000)
        print('---------------------------------')
# Out:
# experimetn start:  0.0 0.0
# 絶対解約率:0.00%
# 100000 0 0
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.0 0.1
# 絶対解約率:10.00%
# 94873.59307193794 10086 0
# 解約力経由:10.09%
# 長さ伸長方式:10.09%
# 長さ非伸長方式:10.63%
# ---------------------------------
# experimetn start:  0.0 0.2
# 絶対解約率:20.00%
# 89468.8536580837 20303 0
# 解約力経由:20.30%
# 長さ伸長方式:20.30%
# 長さ非伸長方式:22.69%
# ---------------------------------
# experimetn start:  0.0 0.30000000000000004
# 絶対解約率:30.00%
# 84128.68283778815 30072 0
# 解約力経由:30.05%
# 長さ伸長方式:30.07%
# 長さ非伸長方式:35.75%
# ---------------------------------
# experimetn start:  0.0 0.4
# 絶対解約率:40.00%
# 78250.08914178508 39936 0
# 解約力経由:39.97%
# 長さ伸長方式:39.94%
# 長さ非伸長方式:51.04%
# ---------------------------------
# experimetn start:  0.0 0.5
# 絶対解約率:50.00%
# 71951.01200088234 50365 0
# 解約力経由:50.34%
# 長さ伸長方式:50.37%
# 長さ非伸長方式:70.00%
# ---------------------------------
# experimetn start:  0.0 0.6000000000000001
# 絶対解約率:60.00%
# 65310.0384836757 60233 0
# 解約力経由:60.24%
# 長さ伸長方式:60.23%
# 長さ非伸長方式:92.23%
# ---------------------------------
# experimetn start:  0.0 0.7000000000000001
# 絶対解約率:70.00%
# 57920.50959248405 70263 0
# 解約力経由:70.27%
# 長さ伸長方式:70.26%
# 長さ非伸長方式:121.31%
# ---------------------------------
# experimetn start:  0.0 0.8
# 絶対解約率:80.00%
# 49800.40606230677 80016 0
# 解約力経由:79.95%
# 長さ伸長方式:80.02%
# 長さ非伸長方式:160.67%
# ---------------------------------
# experimetn start:  0.0 0.9
# 絶対解約率:90.00%
# 39055.924000782994 89947 0
# 解約力経由:90.00%
# 長さ伸長方式:89.95%
# 長さ非伸長方式:230.30%
# ---------------------------------
# experimetn start:  0.1 0.0
# 絶対解約率:0.00%
# 94922.54683290432 0 9970
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.1 0.1
# 絶対解約率:10.00%
# 90308.44837181448 9303 9507
# 解約力経由:9.79%
# 長さ伸長方式:9.78%
# 長さ非伸長方式:10.30%
# ---------------------------------
# experimetn start:  0.1 0.2
# 絶対解約率:20.00%
# 85182.54435374014 19171 8938
# 解約力経由:20.15%
# 長さ伸長方式:20.11%
# 長さ非伸長方式:22.51%
# ---------------------------------
# experimetn start:  0.1 0.30000000000000004
# 絶対解約率:30.00%
# 79896.71730672335 28806 8531
# 解約力経由:30.27%
# 長さ伸長方式:30.19%
# 長さ非伸長方式:36.05%
# ---------------------------------
# experimetn start:  0.1 0.4
# 絶対解約率:40.00%
# 74630.3396742801 38310 7792
# 解約力経由:40.15%
# 長さ伸長方式:40.03%
# 長さ非伸長方式:51.33%
# ---------------------------------
# experimetn start:  0.1 0.5
# 絶対解約率:50.00%
# 68947.8153821046 47778 7180
# 解約力経由:49.99%
# 長さ伸長方式:49.81%
# 長さ非伸長方式:69.30%
# ---------------------------------
# experimetn start:  0.1 0.6000000000000001
# 絶対解約率:60.00%
# 62511.39050963426 57562 6614
# 解約力経由:60.18%
# 長さ伸長方式:59.88%
# 長さ非伸長方式:92.08%
# ---------------------------------
# experimetn start:  0.1 0.7000000000000001
# 絶対解約率:70.00%
# 55817.84491945279 67092 5886
# 解約力経由:69.94%
# 長さ伸長方式:69.57%
# 長さ非伸長方式:120.20%
# ---------------------------------
# experimetn start:  0.1 0.8
# 絶対解約率:80.00%
# 47795.66854481202 76887 5066
# 解約力経由:79.98%
# 長さ伸長方式:79.42%
# 長さ非伸長方式:160.87%
# ---------------------------------
# experimetn start:  0.1 0.9
# 絶対解約率:90.00%
# 37819.33839250808 87011 3987
# 解約力経由:89.98%
# 長さ伸長方式:89.44%
# 長さ非伸長方式:230.07%
# ---------------------------------
# experimetn start:  0.2 0.0
# 絶対解約率:0.00%
# 89711.19889067097 0 19824
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.2 0.1
# 絶対解約率:10.00%
# 85357.64647181591 8853 18920
# 解約力経由:9.85%
# 長さ伸長方式:9.83%
# 長さ非伸長方式:10.37%
# ---------------------------------
# experimetn start:  0.2 0.2
# 絶対解約率:20.00%
# 80428.88531651317 18318 18121
# 解約力経由:20.37%
# 長さ伸長方式:20.30%
# 長さ非伸長方式:22.78%
# ---------------------------------
# experimetn start:  0.2 0.30000000000000004
# 絶対解約率:30.00%
# 75909.52339115132 27325 16813
# 解約力経由:30.23%
# 長さ伸長方式:30.09%
# 長さ非伸長方式:36.00%
# ---------------------------------
# experimetn start:  0.2 0.4
# 絶対解約率:40.00%
# 70821.36093916952 36175 15774
# 解約力経由:40.00%
# 長さ伸長方式:39.69%
# 長さ非伸長方式:51.08%
# ---------------------------------
# experimetn start:  0.2 0.5
# 絶対解約率:50.00%
# 65408.92000214974 45400 14534
# 解約力経由:50.05%
# 長さ伸長方式:49.57%
# 長さ非伸長方式:69.41%
# ---------------------------------
# experimetn start:  0.2 0.6000000000000001
# 絶対解約率:60.00%
# 59582.40638339523 54793 13415
# 解約力経由:60.13%
# 長さ伸長方式:59.53%
# 長さ非伸長方式:91.96%
# ---------------------------------
# experimetn start:  0.2 0.7000000000000001
# 絶対解約率:70.00%
# 53178.483534288025 64148 12011
# 解約力経由:70.07%
# 長さ伸長方式:69.30%
# 長さ非伸長方式:120.63%
# ---------------------------------
# experimetn start:  0.2 0.8
# 絶対解約率:80.00%
# 45786.407193237595 73730 10408
# 解約力経由:80.02%
# 長さ伸長方式:79.06%
# 長さ非伸長方式:161.03%
# ---------------------------------
# experimetn start:  0.2 0.9
# 絶対解約率:90.00%
# 36427.25312399758 83851 8105
# 解約力経由:89.99%
# 長さ伸長方式:88.85%
# 長さ非伸長方式:230.19%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.0
# 絶対解約率:0.00%
# 84113.01135637525 0 30056
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.1
# 絶対解約率:10.00%
# 80003.54252665662 8409 28826
# 解約力経由:9.98%
# 長さ伸長方式:9.95%
# 長さ非伸長方式:10.51%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.2
# 絶対解約率:20.00%
# 75920.51177265302 16977 27127
# 解約力経由:20.04%
# 長さ伸長方式:19.93%
# 長さ非伸長方式:22.36%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.30000000000000004
# 絶対解約率:30.00%
# 71373.24744462316 25491 25591
# 解約力経由:30.03%
# 長さ伸長方式:29.77%
# 長さ非伸長方式:35.72%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.4
# 絶対解約率:40.00%
# 66574.85597214228 34407 24022
# 解約力経由:40.36%
# 長さ伸長方式:39.86%
# 長さ非伸長方式:51.68%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.5
# 絶対解約率:50.00%
# 61800.459358228494 42862 22283
# 解約力経由:50.02%
# 長さ伸長方式:49.31%
# 長さ非伸長方式:69.36%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.6000000000000001
# 絶対解約率:60.00%
# 56391.304172898206 52017 20188
# 解約力経由:60.24%
# 長さ伸長方式:59.22%
# 長さ非伸長方式:92.24%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.7000000000000001
# 絶対解約率:70.00%
# 50619.32214831063 60945 18118
# 解約力経由:70.00%
# 長さ伸長方式:68.73%
# 長さ非伸長方式:120.40%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.8
# 絶対解約率:80.00%
# 43788.33858346367 70200 15705
# 解約力経由:79.87%
# 長さ伸長方式:78.26%
# 長さ非伸長方式:160.32%
# ---------------------------------
# experimetn start:  0.30000000000000004 0.9
# 絶対解約率:90.00%
# 34910.81906846641 80786 12367
# 解約力経由:90.11%
# 長さ伸長方式:88.41%
# 長さ非伸長方式:231.41%
# ---------------------------------
# experimetn start:  0.4 0.0
# 絶対解約率:0.00%
# 78194.73044450127 0 40203
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.4 0.1
# 絶対解約率:10.00%
# 74614.75314356394 7830 38088
# 解約力経由:9.96%
# 長さ伸長方式:9.92%
# 長さ非伸長方式:10.49%
# ---------------------------------
# experimetn start:  0.4 0.2
# 絶対解約率:20.00%
# 70775.47330185278 15897 36406
# 解約力経由:20.12%
# 長さ伸長方式:19.95%
# 長さ非伸長方式:22.46%
# ---------------------------------
# experimetn start:  0.4 0.30000000000000004
# 絶対解約率:30.00%
# 66714.01205593991 23905 34208
# 解約力経由:30.12%
# 長さ伸長方式:29.70%
# 長さ非伸長方式:35.83%
# ---------------------------------
# experimetn start:  0.4 0.4
# 絶対解約率:40.00%
# 62547.737850084304 32129 31939
# 解約力経由:40.17%
# 長さ伸長方式:39.51%
# 長さ非伸長方式:51.37%
# ---------------------------------
# experimetn start:  0.4 0.5
# 絶対解約率:50.00%
# 58140.98522988293 40268 29785
# 解約力経由:49.97%
# 長さ伸長方式:48.93%
# 長さ非伸長方式:69.26%
# ---------------------------------
# experimetn start:  0.4 0.6000000000000001
# 絶対解約率:60.00%
# 53226.623271554796 48682 27392
# 解約力経由:59.93%
# 長さ伸長方式:58.55%
# 長さ非伸長方式:91.46%
# ---------------------------------
# experimetn start:  0.4 0.7000000000000001
# 絶対解約率:70.00%
# 47684.80100176342 57698 24382
# 解約力経由:70.18%
# 長さ伸長方式:68.31%
# 長さ非伸長方式:121.00%
# ---------------------------------
# experimetn start:  0.4 0.8
# 絶対解約率:80.00%
# 41431.67673566845 66923 21054
# 解約力経由:80.12%
# 長さ伸長方式:77.83%
# 長さ非伸長方式:161.53%
# ---------------------------------
# experimetn start:  0.4 0.9
# 絶対解約率:90.00%
# 33387.67730478697 76948 17066
# 解約力経由:90.02%
# 長さ伸長方式:87.53%
# 長さ非伸長方式:230.47%
# ---------------------------------
# experimetn start:  0.5 0.0
# 絶対解約率:0.00%
# 72351.57652623838 0 49734
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.5 0.1
# 絶対解約率:10.00%
# 69065.30882899383 7261 47542
# 解約力経由:9.98%
# 長さ伸長方式:9.92%
# 長さ非伸長方式:10.51%
# ---------------------------------
# experimetn start:  0.5 0.2
# 絶対解約率:20.00%
# 65679.41163652901 14416 45359
# 解約力経由:19.71%
# 長さ伸長方式:19.50%
# 長さ非伸長方式:21.95%
# ---------------------------------
# experimetn start:  0.5 0.30000000000000004
# 絶対解約率:30.00%
# 61894.182356481106 22118 42792
# 解約力経由:30.05%
# 長さ伸長方式:29.55%
# 長さ非伸長方式:35.74%
# ---------------------------------
# experimetn start:  0.5 0.4
# 絶対解約率:40.00%
# 58105.33541477067 30001 40093
# 解約力経由:40.33%
# 長さ伸長方式:39.44%
# 長さ非伸長方式:51.63%
# ---------------------------------
# experimetn start:  0.5 0.5
# 絶対解約率:50.00%
# 54088.663464254016 37435 37642
# 解約力経由:49.95%
# 長さ伸長方式:48.65%
# 長さ非伸長方式:69.21%
# ---------------------------------
# experimetn start:  0.5 0.6000000000000001
# 絶対解約率:60.00%
# 49697.308857430005 45458 34575
# 解約力経由:59.94%
# 長さ伸長方式:58.12%
# 長さ非伸長方式:91.47%
# ---------------------------------
# experimetn start:  0.5 0.7000000000000001
# 絶対解約率:70.00%
# 44847.63673743623 53897 31091
# 解約力経由:69.93%
# 長さ伸長方式:67.45%
# 長さ非伸長方式:120.18%
# ---------------------------------
# experimetn start:  0.5 0.8
# 絶対解約率:80.00%
# 39276.356435762966 63029 26855
# 解約力経由:79.91%
# 長さ伸長方式:77.02%
# 長さ非伸長方式:160.48%
# ---------------------------------
# experimetn start:  0.5 0.9
# 絶対解約率:90.00%
# 31739.538093157895 72971 22004
# 解約力経由:89.96%
# 長さ伸長方式:86.72%
# 長さ非伸長方式:229.91%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.0
# 絶対解約率:0.00%
# 65553.68541236545 0 60000
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.1
# 絶対解約率:10.00%
# 62607.57412752029 6523 57480
# 解約力経由:9.89%
# 長さ伸長方式:9.82%
# 長さ非伸長方式:10.42%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.2
# 絶対解約率:20.00%
# 59541.15055876633 13303 54811
# 解約力経由:20.02%
# 長さ伸長方式:19.73%
# 長さ非伸長方式:22.34%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 56573.77640561325 20074 51991
# 解約力経由:29.87%
# 長さ伸長方式:29.22%
# 長さ非伸長方式:35.48%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.4
# 絶対解約率:40.00%
# 53305.965613686276 27254 48619
# 解約力経由:40.03%
# 長さ伸長方式:38.91%
# 長さ非伸長方式:51.13%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.5
# 絶対解約率:50.00%
# 49739.37737144388 34316 45594
# 解約力経由:49.84%
# 長さ伸長方式:48.09%
# 長さ非伸長方式:68.99%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 45652.16620360547 42099 42051
# 解約力経由:60.23%
# 長さ伸長方式:57.83%
# 長さ非伸長方式:92.22%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 41584.137106111106 49756 38191
# 解約力経由:69.78%
# 長さ伸長方式:66.66%
# 長さ非伸長方式:119.65%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.8
# 絶対解約率:80.00%
# 36534.81765138324 58522 33359
# 解約力経由:79.85%
# 長さ伸長方式:76.10%
# 長さ非伸長方式:160.18%
# ---------------------------------
# experimetn start:  0.6000000000000001 0.9
# 絶対解約率:90.00%
# 29854.498167397524 68663 27351
# 解約力経由:89.97%
# 長さ伸長方式:85.84%
# 長さ非伸長方式:229.99%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.0
# 絶対解約率:0.00%
# 58028.99589006687 0 69941
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.1
# 絶対解約率:10.00%
# 55550.36355391349 5879 67298
# 解約力経由:10.04%
# 長さ伸長方式:9.95%
# 長さ非伸長方式:10.58%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.2
# 絶対解約率:20.00%
# 53381.28932709637 11784 64204
# 解約力経由:19.81%
# 長さ伸長方式:19.43%
# 長さ非伸長方式:22.08%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.30000000000000004
# 絶対解約率:30.00%
# 50746.366053235906 17820 61128
# 解約力経由:29.61%
# 長さ伸長方式:28.82%
# 長さ非伸長方式:35.12%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.4
# 絶対解約率:40.00%
# 47835.67595551019 24481 57580
# 解約力経由:40.06%
# 長さ伸長方式:38.61%
# 長さ非伸長方式:51.18%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.5
# 絶対解約率:50.00%
# 44846.100927684936 30756 54255
# 解約力経由:49.63%
# 長さ伸長方式:47.49%
# 長さ非伸長方式:68.58%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.6000000000000001
# 絶対解約率:60.00%
# 41576.9787112863 37910 50096
# 解約力経由:59.82%
# 長さ伸長方式:56.81%
# 長さ非伸長方式:91.18%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.7000000000000001
# 絶対解約率:70.00%
# 37688.95240363112 45587 45381
# 解約力経由:70.17%
# 長さ伸長方式:66.16%
# 長さ非伸長方式:120.96%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.8
# 絶対解約率:80.00%
# 33282.79078155109 53899 40248
# 解約力経由:80.20%
# 長さ伸長方式:75.40%
# 長さ非伸長方式:161.94%
# ---------------------------------
# experimetn start:  0.7000000000000001 0.9
# 絶対解約率:90.00%
# 27600.935495844507 63638 33383
# 解約力経由:90.03%
# 長さ伸長方式:84.71%
# 長さ非伸長方式:230.56%
# ---------------------------------
# experimetn start:  0.8 0.0
# 絶対解約率:0.00%
# 49664.349651206896 0 80124
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.8 0.1
# 絶対解約率:10.00%
# 47634.27650463153 4999 76945
# 解約力経由:9.96%
# 長さ伸長方式:9.84%
# 長さ非伸長方式:10.49%
# ---------------------------------
# experimetn start:  0.8 0.2
# 絶対解約率:20.00%
# 45830.71761139906 10261 73714
# 解約力経由:20.06%
# 長さ伸長方式:19.57%
# 長さ非伸長方式:22.39%
# ---------------------------------
# experimetn start:  0.8 0.30000000000000004
# 絶対解約率:30.00%
# 43760.68735056909 15594 70197
# 解約力経由:29.98%
# 長さ伸長方式:28.91%
# 長さ非伸長方式:35.63%
# ---------------------------------
# experimetn start:  0.8 0.4
# 絶対解約率:40.00%
# 41445.6388997128 21184 66777
# 解約力経由:40.02%
# 長さ伸長方式:38.15%
# 長さ非伸長方式:51.11%
# ---------------------------------
# experimetn start:  0.8 0.5
# 絶対解約率:50.00%
# 39097.62772539058 27182 62846
# 解約力経由:50.10%
# 長さ伸長方式:47.26%
# 長さ非伸長方式:69.52%
# ---------------------------------
# experimetn start:  0.8 0.6000000000000001
# 絶対解約率:60.00%
# 36414.48236289637 33575 58437
# 解約力経由:60.23%
# 長さ伸長方式:56.27%
# 長さ非伸長方式:92.20%
# ---------------------------------
# experimetn start:  0.8 0.7000000000000001
# 絶対解約率:70.00%
# 33324.518646788456 40211 53816
# 解約力経由:70.08%
# 長さ伸長方式:65.00%
# 長さ非伸長方式:120.66%
# ---------------------------------
# experimetn start:  0.8 0.8
# 絶対解約率:80.00%
# 29898.747338698642 48002 47934
# 解約力経由:79.92%
# 長さ伸長方式:73.84%
# 長さ非伸長方式:160.55%
# ---------------------------------
# experimetn start:  0.8 0.9
# 絶対解約率:90.00%
# 25108.618679477855 57801 40209
# 解約力経由:89.99%
# 長さ伸長方式:83.39%
# 長さ非伸長方式:230.20%
# ---------------------------------
# experimetn start:  0.9 0.0
# 絶対解約率:0.00%
# 38910.94662651348 0 90068
# 解約力経由:0.00%
# 長さ伸長方式:0.00%
# 長さ非伸長方式:0.00%
# ---------------------------------
# experimetn start:  0.9 0.1
# 絶対解約率:10.00%
# 37888.86882029713 4099 86778
# 解約力経由:10.25%
# 長さ伸長方式:10.08%
# 長さ非伸長方式:10.82%
# ---------------------------------
# experimetn start:  0.9 0.2
# 絶対解約率:20.00%
# 36308.51592043473 8242 83814
# 解約力経由:20.31%
# 長さ伸長方式:19.61%
# 長さ非伸長方式:22.70%
# ---------------------------------
# experimetn start:  0.9 0.30000000000000004
# 絶対解約率:30.00%
# 34921.95385321651 12380 80704
# 解約力経由:29.85%
# 長さ伸長方式:28.39%
# 長さ非伸長方式:35.45%
# ---------------------------------
# experimetn start:  0.9 0.4
# 絶対解約率:40.00%
# 33350.616323004666 17174 76877
# 解約力経由:40.25%
# 長さ伸長方式:37.76%
# 長さ非伸長方式:51.50%
# ---------------------------------
# experimetn start:  0.9 0.5
# 絶対解約率:50.00%
# 31689.2151397266 22149 72862
# 解約力経由:50.29%
# 長さ伸長方式:46.56%
# 長さ非伸長方式:69.89%
# ---------------------------------
# experimetn start:  0.9 0.6000000000000001
# 絶対解約率:60.00%
# 29873.29198112898 27317 68588
# 解約力経由:59.93%
# 長さ伸長方式:54.88%
# 長さ非伸長方式:91.44%
# ---------------------------------
# experimetn start:  0.9 0.7000000000000001
# 絶対解約率:70.00%
# 27685.00421605217 33343 63593
# 解約力経由:70.01%
# 長さ伸長方式:63.45%
# 長さ非伸長方式:120.44%
# ---------------------------------
# experimetn start:  0.9 0.8
# 絶対解約率:80.00%
# 25134.304075957993 40409 57582
# 解約力経由:79.97%
# 長さ伸長方式:72.10%
# 長さ非伸長方式:160.77%
# ---------------------------------
# experimetn start:  0.9 0.9
# 絶対解約率:90.00%
# 21439.429862763354 49494 49481
# 解約力経由:90.06%
# 長さ伸長方式:81.57%
# 長さ非伸長方式:230.86%
# ---------------------------------

# %%
pd.DataFrame(
    {'am':AM, 'al':AL, 'a':a,'b':b,'c':c}
).to_csv('./result.csv')
